# %%
import numpyro
from numpyro.infer.autoguide import AutoMultivariateNormal
import pandas as pd

# %%
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir) 
from src.rt_from_frequency_dynamics import *

# %% [markdown]
# # Run multiple states

# %%
raw_cases = pd.read_csv("../../rt-from-frequency-dynamics/data/location-case-counts.tsv", sep="\t")
raw_seq = pd.read_csv("../../rt-from-frequency-dynamics/data/location-variant-sequence-counts.tsv", sep="\t")

# %%
def run_SVI(LD, optimizer, num_samples=1000, iters=100_000, name="test", path=".", save=True, export=True, load=False):       
    X = make_breakpoint_splines(LD.cases, 20)
    data = LD.make_numpyro_input(X)

    # Defining model
    g, delays = get_standard_delays()
    LM = FreeGrowthModel(g, delays, 7, 0)

    # Run SVI
    SVIH = SVIHandler(optimizer=optimizer)
    guide = AutoMultivariateNormal(LM.model)
    
    if load:
        SVIH.load_state(f"{path}/models/{name}_svi.p")
    
    loss = SVIH.fit(LM.model, guide, data, iters, log_each=0)
    print(f"Model {name} finished. Final loss: {loss}")
    
    if jnp.isnan(loss):
        return False
    if save:
        SVIH.save_state(f"{path}/models/{name}_svi.p")
    
    # Get samples
    samples = SVIH.predict(LM.model, guide, data, num_samples=num_samples)
    dataset = to_arviz(samples)
    
    if export:
        # Get dataframes
        R_dataframe = pd.DataFrame(get_R(dataset, LD, ps, name))    
        R_dataframe.to_csv(f"{path}/Rt/Rt_{name}.csv", encoding='utf-8', index=False)
    return True

# %%
def get_state_LD(rc, rs, loc):
    rc_l = rc[rc.location == loc].copy()
    rs_l = rs[rs.location==loc].copy()
    return LineageData(rc_l, rs_l)

def run_locations(rc, rs, locations, optimizer, **kwargs):
    n_locations = len(locations)
    sucesses = []
    for i, loc in enumerate(locations):
        LD = get_state_LD(raw_cases, raw_seq, loc)
        model_name = loc.replace(" ", "_")
        sucess = run_SVI(LD, optimizer, name=model_name, **kwargs)
        sucesses.append(sucess)
        print(f'Location {loc} finished ({i+1}/{n_locations}).')
    return locations[sucesses]

# %%
ps = DefaultAes.ps

# %%
locations = pd.unique(raw_seq.location)

optimizer = numpyro.optim.Adam(step_size=1.0e-2)
num_samples = 1500
iters = 50_000
path = "../sims/all-states-preprint-free"
save = True
export = True
load = False
succeded = run_locations(raw_cases, raw_seq, locations, optimizer, 
              num_samples=num_samples, iters=iters, path=path, save=save, export=export, load=load)
# Out:
# Model Alabama finished. Final loss: 3405.12548828125
# Location Alabama finished (1/39).
# Model Alaska finished. Final loss: 2793.943603515625
# Location Alaska finished (2/39).
# Model Arizona finished. Final loss: 4381.81787109375
# Location Arizona finished (3/39).
# Model Arkansas finished. Final loss: 2813.24951171875
# Location Arkansas finished (4/39).
# Model California finished. Final loss: 6552.666015625
# Location California finished (5/39).
# Model Colorado finished. Final loss: 4281.517578125
# Location Colorado finished (6/39).
# Model Connecticut finished. Final loss: 3606.1328125
# Location Connecticut finished (7/39).
# Model Florida finished. Final loss: 6355.2958984375
# Location Florida finished (8/39).
# Model Georgia finished. Final loss: 4460.96484375
# Location Georgia finished (9/39).
# Model Idaho finished. Final loss: 2717.18017578125
# Location Idaho finished (10/39).
# Model Illinois finished. Final loss: 4412.9169921875
# Location Illinois finished (11/39).
# Model Indiana finished. Final loss: 3781.42333984375
# Location Indiana finished (12/39).
# Model Kentucky finished. Final loss: 3078.4599609375
# Location Kentucky finished (13/39).
# Model Louisiana finished. Final loss: 3448.320556640625
# Location Louisiana finished (14/39).
# Model Maryland finished. Final loss: 4110.8505859375
# Location Maryland finished (15/39).
# Model Massachusetts finished. Final loss: 4817.1025390625
# Location Massachusetts finished (16/39).
# Model Michigan finished. Final loss: 3894.520751953125
# Location Michigan finished (17/39).
# Model Minnesota finished. Final loss: 4969.09130859375
# Location Minnesota finished (18/39).
# Model Missouri finished. Final loss: 3432.075927734375
# Location Missouri finished (19/39).
# Model Nevada finished. Final loss: 3513.99755859375
# Location Nevada finished (20/39).
# Model New_Hampshire finished. Final loss: 2909.252197265625
# Location New Hampshire finished (21/39).
# Model New_Jersey finished. Final loss: 4602.6513671875
# Location New Jersey finished (22/39).
# Model New_Mexico finished. Final loss: 3468.564453125
# Location New Mexico finished (23/39).
# Model New_York finished. Final loss: 4399.05517578125
# Location New York finished (24/39).
# Model North_Carolina finished. Final loss: 4663.2607421875
# Location North Carolina finished (25/39).
# Model Ohio finished. Final loss: 4078.59814453125
# Location Ohio finished (26/39).
# Model Oklahoma finished. Final loss: 2586.161865234375
# Location Oklahoma finished (27/39).
# Model Oregon finished. Final loss: 3604.067138671875
# Location Oregon finished (28/39).
# Model Pennsylvania finished. Final loss: 4569.083984375
# Location Pennsylvania finished (29/39).
# Model Rhode_Island finished. Final loss: 3078.677490234375
# Location Rhode Island finished (30/39).
# Model South_Carolina finished. Final loss: 3540.568359375
# Location South Carolina finished (31/39).
# Model Tennessee finished. Final loss: 3803.12744140625
# Location Tennessee finished (32/39).
# Model Texas finished. Final loss: 5763.154296875
# Location Texas finished (33/39).
# Model Utah finished. Final loss: 3221.1533203125
# Location Utah finished (34/39).
# Model Vermont finished. Final loss: 2116.95703125
# Location Vermont finished (35/39).
# Model Virginia finished. Final loss: 3997.7783203125
# Location Virginia finished (36/39).
# Model Washington finished. Final loss: 4720.7216796875
# Location Washington finished (37/39).
# Model West_Virginia finished. Final loss: 3257.272705078125
# Location West Virginia finished (38/39).
# Model Wisconsin finished. Final loss: 3438.940673828125
# Location Wisconsin finished (39/39).

# %%
failed_locations = [l for l in locations if l not in succeded]
failed_locations
# Out:
# []

# %%
def combine_exports(rc, rs, locations, path):   
    rt_list = []
    for i, loc in enumerate(locations):
        _loc = loc.replace(" ", "_")
        rt_list.append(pd.read_csv(f"{path}/Rt/Rt_{_loc}.csv"))
    return pd.concat(rt_list)

# %%
rt_df = combine_exports(raw_cases, raw_seq, locations, path)

# %%
rt_df
# Out:
#             date   location variant  median_R  median_freq  R_upper_95  \
# 0     2021-01-02    Alabama   Alpha  1.073730     0.018817    1.550390
# 1     2021-01-03    Alabama   Alpha  1.096541     0.018817    1.524041
# 2     2021-01-04    Alabama   Alpha  1.117060     0.018819    1.496823
# 3     2021-01-05    Alabama   Alpha  1.130633     0.018870    1.505939
# 4     2021-01-06    Alabama   Alpha  1.142889     0.019105    1.526867
# ...          ...        ...     ...       ...          ...         ...
# 2187  2021-09-27  Wisconsin   other  1.284883     0.018166    1.487702
# 2188  2021-09-28  Wisconsin   other  1.276162     0.018601    1.501597
# 2189  2021-09-29  Wisconsin   other  1.263589     0.019162    1.528038
# 2190  2021-09-30  Wisconsin   other  1.252354     0.019754    1.565484
# 2191  2021-10-01  Wisconsin   other  1.237500     0.020282    1.595212
#
#       R_lower_95  R_upper_80  R_lower_80  R_upper_50  R_lower_50
# 0       0.701531    1.355073    0.811848    1.198824    0.912277
# 1       0.767612    1.351724    0.857391    1.210157    0.952431
# 2       0.774870    1.359018    0.892498    1.196342    0.952845
# 3       0.795053    1.365812    0.915992    1.230100    0.994914
# 4       0.817361    1.364859    0.924115    1.218689    0.984211
# ...          ...         ...         ...         ...         ...
# 2187    1.079312    1.410236    1.145974    1.339500    1.206707
# 2188    1.060867    1.427426    1.143375    1.314946    1.176185
# 2189    1.039983    1.409146    1.099998    1.316110    1.164876
# 2190    1.010273    1.414665    1.077569    1.333336    1.165390
# 2191    0.965936    1.414529    1.027243    1.312735    1.120636
#
# [84447 rows x 11 columns]

# %%
rt_df.to_csv(f"{path}/Rt/Rt_combined.csv", encoding='utf-8', index=False)
