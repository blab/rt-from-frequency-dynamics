# %%
import numpyro
from numpyro.infer.autoguide import AutoMultivariateNormal
import pandas as pd

# %%
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir) 
from src.rt_from_frequency_dynamics import *

# %% [markdown]
# # Run multiple states

# %%
raw_cases = pd.read_csv("../../rt-from-frequency-dynamics/data/location-case-counts.tsv", sep="\t")
raw_seq = pd.read_csv("../../rt-from-frequency-dynamics/data/location-variant-sequence-counts.tsv", sep="\t")

# %%
def run_SVI(LD, optimizer, num_samples=1000, iters=100_000, name="test", path=".", save=True, export=True, load=False):       
    X = make_breakpoint_splines(LD.cases, 20)
    data = LD.make_numpyro_input(X)

    # Defining model
    g, delays = get_standard_delays()
    LM = FixedGrowthModel(g, delays, 7, 0)

    # Run SVI
    SVIH = SVIHandler(optimizer=optimizer)
    guide = AutoMultivariateNormal(LM.model)
    
    if load:
        SVIH.load_state(f"{path}/models/{name}_svi.p")
    
    loss = SVIH.fit(LM.model, guide, data, iters, log_each=0)
    print(f"Model {name} finished. Final loss: {loss}")
    
    if jnp.isnan(loss):
        return False
    if save:
        SVIH.save_state(f"{path}/models/{name}_svi.p")
    
    # Get samples
    samples = SVIH.predict(LM.model, guide, data, num_samples=num_samples)
    dataset = to_arviz(samples)
    
    if export:
        # Get dataframes
        R_dataframe = pd.DataFrame(get_R(dataset, LD, ps, name))
        ga_dataframe = pd.DataFrame(get_growth_advantage(dataset, LD, ps, name))
    
        R_dataframe.to_csv(f"{path}/Rt/Rt_{name}.csv", encoding='utf-8', index=False)
        ga_dataframe.to_csv(f"{path}/ga/ga_{name}.csv", encoding='utf-8', index=False)
    return True

# %%
def get_state_LD(rc, rs, loc):
    rc_l = rc[rc.location == loc].copy()
    rs_l = rs[rs.location==loc].copy()
    return LineageData(rc_l, rs_l)

def run_locations(rc, rs, locations, optimizer, **kwargs):
    n_locations = len(locations)
    sucesses = []
    for i, loc in enumerate(locations):
        LD = get_state_LD(raw_cases, raw_seq, loc)
        model_name = loc.replace(" ", "_")
        sucess = run_SVI(LD, optimizer, name=model_name, **kwargs)
        sucesses.append(sucess)
        print(f'Location {loc} finished ({i+1}/{n_locations}).')
    return locations[sucesses]

# %%
ps = DefaultAes.ps

# %%
locations = pd.unique(raw_seq.location)

optimizer = numpyro.optim.Adam(step_size=1.0e-2)
num_samples = 1500
iters = 50_000
path = "../sims/all-states-preprint-fixed"
save = True
export = True
load = False
succeded = run_locations(raw_cases, raw_seq, locations, optimizer, 
              num_samples=num_samples, iters=iters, path=path, save=save, export=export, load=load)
# Out:
# Model Alabama finished. Final loss: 3424.47216796875
# Location Alabama finished (1/39).
# Model Alaska finished. Final loss: 2735.58056640625
# Location Alaska finished (2/39).
# Model Arizona finished. Final loss: 4603.634765625
# Location Arizona finished (3/39).
# Model Arkansas finished. Final loss: 2814.448486328125
# Location Arkansas finished (4/39).
# Model California finished. Final loss: 7058.9541015625
# Location California finished (5/39).
# Model Colorado finished. Final loss: 4430.9453125
# Location Colorado finished (6/39).
# Model Connecticut finished. Final loss: 3607.63232421875
# Location Connecticut finished (7/39).
# Model Florida finished. Final loss: 6995.302734375
# Location Florida finished (8/39).
# Model Georgia finished. Final loss: 4691.76171875
# Location Georgia finished (9/39).
# Model Idaho finished. Final loss: 2719.794921875
# Location Idaho finished (10/39).
# Model Illinois finished. Final loss: 4654.9423828125
# Location Illinois finished (11/39).
# Model Indiana finished. Final loss: 3819.692626953125
# Location Indiana finished (12/39).
# Model Kentucky finished. Final loss: 3032.1962890625
# Location Kentucky finished (13/39).
# Model Louisiana finished. Final loss: 3463.8505859375
# Location Louisiana finished (14/39).
# Model Maryland finished. Final loss: 4210.30859375
# Location Maryland finished (15/39).
# Model Massachusetts finished. Final loss: 5152.06884765625
# Location Massachusetts finished (16/39).
# Model Michigan finished. Final loss: 4028.98095703125
# Location Michigan finished (17/39).
# Model Minnesota finished. Final loss: 5222.56298828125
# Location Minnesota finished (18/39).
# Model Missouri finished. Final loss: 3458.255126953125
# Location Missouri finished (19/39).
# Model Nevada finished. Final loss: 3525.16845703125
# Location Nevada finished (20/39).
# Model New_Hampshire finished. Final loss: 2894.62353515625
# Location New Hampshire finished (21/39).
# Model New_Jersey finished. Final loss: 4724.3544921875
# Location New Jersey finished (22/39).
# Model New_Mexico finished. Final loss: 3425.45458984375
# Location New Mexico finished (23/39).
# Model New_York finished. Final loss: 4707.2734375
# Location New York finished (24/39).
# Model North_Carolina finished. Final loss: 5022.45703125
# Location North Carolina finished (25/39).
# Model Ohio finished. Final loss: 4269.373046875
# Location Ohio finished (26/39).
# Model Oklahoma finished. Final loss: 2669.68896484375
# Location Oklahoma finished (27/39).
# Model Oregon finished. Final loss: 3611.7451171875
# Location Oregon finished (28/39).
# Model Pennsylvania finished. Final loss: 4702.25341796875
# Location Pennsylvania finished (29/39).
# Model Rhode_Island finished. Final loss: 3051.779296875
# Location Rhode Island finished (30/39).
# Model South_Carolina finished. Final loss: 3638.356689453125
# Location South Carolina finished (31/39).
# Model Tennessee finished. Final loss: 3951.514892578125
# Location Tennessee finished (32/39).
# Model Texas finished. Final loss: 6180.5126953125
# Location Texas finished (33/39).
# Model Utah finished. Final loss: 3260.9189453125
# Location Utah finished (34/39).
# Model Vermont finished. Final loss: 2044.2646484375
# Location Vermont finished (35/39).
# Model Virginia finished. Final loss: 4089.8232421875
# Location Virginia finished (36/39).
# Model Washington finished. Final loss: 4810.9365234375
# Location Washington finished (37/39).
# Model West_Virginia finished. Final loss: 3280.9619140625
# Location West Virginia finished (38/39).
# Model Wisconsin finished. Final loss: 3501.54296875
# Location Wisconsin finished (39/39).

# %%
failed_locations = [l for l in locations if l not in succeded]
failed_locations
# Out:
# []

# %%
def combine_exports(rc, rs, locations, path):   
    rt_list = []
    ga_list = []
    for i, loc in enumerate(locations):
        _loc = loc.replace(" ", "_")
        rt_list.append(pd.read_csv(f"{path}/Rt/Rt_{_loc}.csv"))
        ga_list.append(pd.read_csv(f"{path}/ga/ga_{_loc}.csv"))
    return pd.concat(rt_list), pd.concat(ga_list)

# %%
rt_df, ga_df = combine_exports(raw_cases, raw_seq, locations, path)

# %%
rt_df
# Out:
#             date   location variant  median_R  median_freq  R_upper_95  \
# 0     2021-01-02    Alabama   Alpha  0.836635     0.206123    1.106170
# 1     2021-01-03    Alabama   Alpha  0.834950     0.206123    1.046187
# 2     2021-01-04    Alabama   Alpha  0.830126     0.206125    1.006731
# 3     2021-01-05    Alabama   Alpha  0.827720     0.206222    0.980682
# 4     2021-01-06    Alabama   Alpha  0.826028     0.206807    0.958518
# ...          ...        ...     ...       ...          ...         ...
# 2187  2021-09-27  Wisconsin   other  0.580588     0.000009    0.758534
# 2188  2021-09-28  Wisconsin   other  0.575112     0.000008    0.784677
# 2189  2021-09-29  Wisconsin   other  0.569884     0.000007    0.812579
# 2190  2021-09-30  Wisconsin   other  0.565590     0.000007    0.864555
# 2191  2021-10-01  Wisconsin   other  0.560623     0.000006    0.922522
#
#       R_lower_95  R_upper_80  R_lower_80  R_upper_50  R_lower_50
# 0       0.628429    1.010743    0.691329    0.910063    0.749228
# 1       0.653002    0.956509    0.696619    0.892448    0.760427
# 2       0.676193    0.936606    0.720686    0.875174    0.763146
# 3       0.697525    0.921473    0.740097    0.876328    0.779955
# 4       0.706894    0.901327    0.742232    0.867851    0.784863
# ...          ...         ...         ...         ...         ...
# 2187    0.428158    0.689381    0.471093    0.635712    0.527606
# 2188    0.400988    0.699281    0.446163    0.626731    0.500327
# 2189    0.362373    0.719739    0.420419    0.654209    0.503706
# 2190    0.333752    0.720405    0.367581    0.639298    0.460430
# 2191    0.294531    0.755346    0.340118    0.632436    0.424172
#
# [84447 rows x 11 columns]

# %%
ga_df[ga_df.variant == "Delta"]
# Out:
#          location variant  median_ga  ga_upper_95  ga_lower_95  ga_upper_80  \
# 2         Alabama   Delta   1.444503     1.482694     1.409529     1.465111
# 2          Alaska   Delta   2.049501     2.082941     2.017593     2.070600
# 2         Arizona   Delta   1.804441     1.842422     1.766417     1.828771
# 1        Arkansas   Delta   1.553488     1.594496     1.510766     1.581430
# 2      California   Delta   1.693251     1.735197     1.655827     1.719300
# 2        Colorado   Delta   1.855789     1.873478     1.838230     1.865448
# 2     Connecticut   Delta   1.910323     2.004669     1.812613     1.973063
# 2         Florida   Delta   1.911286     1.925594     1.898726     1.919027
# 2         Georgia   Delta   1.796994     1.811794     1.780459     1.807067
# 2           Idaho   Delta   1.659152     1.740138     1.580142     1.710763
# 2        Illinois   Delta   1.848770     1.862720     1.835087     1.856400
# 2         Indiana   Delta   1.954079     1.976201     1.930266     1.967252
# 2        Kentucky   Delta   1.629659     1.645858     1.613857     1.638500
# 1       Louisiana   Delta   1.704081     1.781782     1.610661     1.758924
# 2        Maryland   Delta   1.812513     1.871863     1.757883     1.845597
# 2   Massachusetts   Delta   1.883865     1.924218     1.844394     1.906476
# 2        Michigan   Delta   1.833718     1.851292     1.817322     1.844025
# 2       Minnesota   Delta   2.233399     2.292848     2.179254     2.268230
# 2        Missouri   Delta   1.546973     1.584307     1.505859     1.570626
# 2          Nevada   Delta   1.721980     1.743988     1.697604     1.735665
